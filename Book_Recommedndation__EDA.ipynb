# %% [markdown]
# # **Project Name**    - Book Recommendation System
# ## Dev- Ashutosh Sharma
# ### **GitHub Link - https://github.com/ashutosh-sharma-xi/Book-Recommendation-System**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
books = pd.read_csv('/content/drive/MyDrive/AlmaBetter /Capstone Project/Book Recommendation System/Book RCD Dataset /Copy of Books.csv')
ratings = pd.read_csv('/content/drive/MyDrive/AlmaBetter /Capstone Project/Book Recommendation System/Book RCD Dataset /Copy of Ratings.csv')
users = pd.read_csv('/content/drive/MyDrive/AlmaBetter /Capstone Project/Book Recommendation System/Book RCD Dataset /Copy of Users.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # **Understanding Books Data**

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.tail(5)
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
for col in books:
  print(col,' : ',books[col].unique(),'\n\n')
# Out:
# ISBN  :  ['0195153448' '0002005018' '0060973129' ... '006008667X' '0192126040'
#  '0767409752']
#
#
# Book-Title  :  ['Classical Mythology' 'Clara Callan' 'Decision in Normandy' ...
#  'Lily Dale : The True Story of the Town that Talks to the Dead'
#  "Republic (World's Classics)"
#  "A Guided Tour of Rene Descartes' Meditations on First Philosophy with Complete Translations of the Meditations by Ronald Rubin"]
#
#
# Book-Author  :  ['Mark P. O. Morford' 'Richard Bruce Wright' "Carlo D'Este" ...
#  'David Biggs' 'Teri Sloat' 'Christopher  Biffle']
#
#
# Year-Of-Publication  :  [2002 2001 1991 1999 2000 1993 1996 1988 2004 1998 1994 2003 1997 1983
#  1979 1995 1982 1985 1992 1986 1978 1980 1952 1987 1990 1981 1989 1984 0
#  1968 1961 1958 1974 1976 1971 1977 1975 1965 1941 1970 1962 1973 1972
#  1960 1966 1920 1956 1959 1953 1951 1942 1963 1964 1969 1954 1950 1967
#  2005 1957 1940 1937 1955 1946 1936 1930 2011 1925 1948 1943 1947 1945
#  1923 2020 1939 1926 1938 2030 1911 1904 1949 1932 1928 1929 1927 1931
#  1914 2050 1934 1910 1933 1902 1924 1921 1900 2038 2026 1944 1917 1901
#  2010 1908 1906 1935 1806 2021 '2000' '1995' '1999' '2004' '2003' '1990'
#  '1994' '1986' '1989' '2002' '1981' '1993' '1983' '1982' '1976' '1991'
#  '1977' '1998' '1992' '1996' '0' '1997' '2001' '1974' '1968' '1987' '1984'
#  '1988' '1963' '1956' '1970' '1985' '1978' '1973' '1980' '1979' '1975'
#  '1969' '1961' '1965' '1939' '1958' '1950' '1953' '1966' '1971' '1959'
#  '1972' '1955' '1957' '1945' '1960' '1967' '1932' '1924' '1964' '2012'
#  '1911' '1927' '1948' '1962' '2006' '1952' '1940' '1951' '1931' '1954'
#  '2005' '1930' '1941' '1944' 'DK Publishing Inc' '1943' '1938' '1900'
#  '1942' '1923' '1920' '1933' 'Gallimard' '1909' '1946' '2008' '1378'
#  '2030' '1936' '1947' '2011' '2020' '1919' '1949' '1922' '1897' '2024'
#  '1376' '1926' '2037']
#
#
# Publisher  :  ['Oxford University Press' 'HarperFlamingo Canada' 'HarperPerennial' ...
#  'Tempo' 'Life Works Books' 'Connaught']
#
#
# Image-URL-S  :  ['http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.THUMBZZZ.jpg']
#
#
# Image-URL-M  :  ['http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.MZZZZZZZ.jpg']
#
#
# Image-URL-L  :  ['http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.LZZZZZZZ.jpg']

# %%
# books that were published before 20th century
books[(books['Year-Of-Publication'] == 0)]
# Out:
#               ISBN                                         Book-Title  \
# 176     3150000335                                   Kabale Und Liebe
# 188     342311360X                            Die Liebe in Den Zelten
# 288     0571197639                        Poisonwood Bible Edition Uk
# 351     3596214629       Herr Der Fliegen (Fiction, Poetry and Drama)
# 542     8845229041  Biblioteca Universale Rizzoli: Sulla Sponda De...
# ...            ...                                                ...
# 270794  014029953X                         Foe (Essential.penguin S.)
# 270913  0340571187                                     Postmens House
# 271094  8427201079                           El Misterio De Sittaford
# 271182  0887781721                                          Tom Penny
# 271196  3150013763                                     Der Hofmeister
#
#                    Book-Author Year-Of-Publication  \
# 176                   Schiller                   0
# 188     Gabriel Garcia Marquez                   0
# 288         Barbara Kingsolver                   0
# 351                    Golding                   0
# 542                   P Coelho                   0
# ...                        ...                 ...
# 270794            J.M. Coetzee                   0
# 270913        Maggie Hemingway                   0
# 271094         Agatha Christie                   0
# 271182             Tony German                   0
# 271196              Jakob Lenz                   0
#
#                                  Publisher  \
# 176        Philipp Reclam, Jun Verlag GmbH
# 188     Deutscher Taschenbuch Verlag (DTV)
# 288                        Faber Faber Inc
# 351        Fischer Taschenbuch Verlag GmbH
# 542                     Fabbri - RCS Libri
# ...                                    ...
# 270794                   Penguin Books Ltd
# 270913                    Trafalgar Square
# 271094                    Editorial Molino
# 271182                P. Martin Associates
# 271196     Philipp Reclam, Jun Verlag GmbH
#
#                                               Image-URL-S  \
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
#                                               Image-URL-M  \
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
#                                               Image-URL-L
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
# [3570 rows x 8 columns]

# %%
import re
# Some Year of publication had title name in place of Year of Publication so dropping them
# get indexes of all those rows and then drop them
drop_indexes = books[books.loc[:,'Year-Of-Publication'].str.contains(pat = 'i[a-z]', regex = True) == True].index
books.drop(index = drop_indexes , inplace = True)

# %%
# convert Year of publication to integer type
books['Year-Of-Publication'] = books['Year-Of-Publication'].astype('int64')

# %%
 # books that were published before 20th century
 books[(books['Year-Of-Publication'] < 1900) & (books['Year-Of-Publication'] > 0)]
# Out:
#               ISBN                                         Book-Title  \
# 171817  0781228956  Complete Works 10 Volumes [2,6,7,8,9] (Notable...
# 227531  9643112136                   Dalan-i bihisht (Dastan-i Irani)
# 245607  0781268001  Hugh Wynne, Free Quaker (2 Volumes (BCL1-PS Am...
# 253750  964442011X                                       Tasht-i khun
#
#                 Book-Author  Year-Of-Publication              Publisher  \
# 171817    Benjamin Franklin                 1806  Reprint Services Corp
# 227531          Nazi Safavi                 1378    Intisharat-i Quqnus
# 245607  Silas Weir Mitchell                 1897  Reprint Services Corp
# 253750       IsmaÂ°il Fasih                 1376         Nashr-i Alburz
#
#                                               Image-URL-S  \
# 171817  http://images.amazon.com/images/P/0781228956.0...
# 227531  http://images.amazon.com/images/P/9643112136.0...
# 245607  http://images.amazon.com/images/P/0781268001.0...
# 253750  http://images.amazon.com/images/P/964442011X.0...
#
#                                               Image-URL-M  \
# 171817  http://images.amazon.com/images/P/0781228956.0...
# 227531  http://images.amazon.com/images/P/9643112136.0...
# 245607  http://images.amazon.com/images/P/0781268001.0...
# 253750  http://images.amazon.com/images/P/964442011X.0...
#
#                                               Image-URL-L
# 171817  http://images.amazon.com/images/P/0781228956.0...
# 227531  http://images.amazon.com/images/P/9643112136.0...
# 245607  http://images.amazon.com/images/P/0781268001.0...
# 253750  http://images.amazon.com/images/P/964442011X.0...

# %%
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author  Year-Of-Publication  \
# 0         Mark P. O. Morford                 2002
# 1       Richard Bruce Wright                 2001
# 2               Carlo D'Este                 1991
# 3           Gina Bari Kolata                 1999
# 4            E. J. W. Barber                 1999
# ...                      ...                  ...
# 271355        Paula Danziger                 1988
# 271356            Teri Sloat                 1991
# 271357      Christine Wicker                 2004
# 271358                 Plato                 1996
# 271359   Christopher  Biffle                 2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271357 rows x 7 columns]

# %%
# some basic data cleaning
# convert all columns to lower case except urls

book_except_url = books.loc[:, ~books.columns.isin([ 'Image-URL-M','Image-URL-S','Image-URL-L'])]
for col in book_except_url:
  try:
    books[col] =  books[col].str.lower()
  except:
    pass

# %%
books['Book-Author'].value_counts()
# Out:
# agatha christie        636
# william shakespeare    570
# stephen king           534
# ann m. martin          423
# francine pascal        419
#                       ...
# keith abbott             1
# josefina r. aldecoa      1
# william o. douglas       1
# clarence meyer           1
# christopher  biffle      1
# Name: Book-Author, Length: 99339, dtype: int64

# %%
# List of books by authors
auth_books = books.groupby(['Book-Author'])['Book-Title'].agg(list)
auth_df = pd.DataFrame(auth_books)
Book_No = [len(c) for c in auth_df['Book-Title']]
auth_df['Number_of_Books'] = Book_No
auth_df.sort_values('Number_of_Books', ascending= 0)
# Out:
#                                                             Book-Title  \
# Book-Author
# agatha christie      [sleeping murder, sleeping murder (miss marple...
# william shakespeare  [julius caesar (oxford school shakespeare), ot...
# stephen king         [the girl who loved tom gordon, pet sematary, ...
# ann m. martin        [karen's school trip (baby-sitters little sist...
# francine pascal      [she's not what she seems (sweet valley high n...
# ...                                                                ...
# j montague                                               [clock tower]
# j martyn walsh                                [plain english handbook]
# j m robertson                                          [pagan christs]
# j m roberts                                        [history of europe]
# ã?â?ric holder                                  [mademoiselle chambon]
#
#                      Number_of_Books
# Book-Author
# agatha christie                  636
# william shakespeare              570
# stephen king                     534
# ann m. martin                    423
# francine pascal                  419
# ...                              ...
# j montague                         1
# j martyn walsh                     1
# j m robertson                      1
# j m roberts                        1
# ã?â?ric holder                     1
#
# [99339 rows x 2 columns]

# %% [markdown]
# # **Understanding Ratings Data**

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.tail()
# Out:
#          User-ID         ISBN  Book-Rating
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
# value count of user id
ratings['User-ID'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: User-ID, Length: 105283, dtype: int64

# %%
# value count of ratings
ratings['Book-Rating'].value_counts()
# Out:
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: Book-Rating, dtype: int64

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %% [markdown]
# # **Understanding Users Data**

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
#Age shows some outliers lets remove them
users[users['Age'] >= 120]
# Out:
#         User-ID                                 Location    Age
# 1578       1579             akure, ondo/nigeria, nigeria  231.0
# 8457       8458                 milano, lombardia, italy  230.0
# 8781       8782                 calgary, alberta, canada  239.0
# 11325     11326      johannesburg, gauteng, south africa  148.0
# 12691     12692               jacksonville, florida, usa  151.0
# ...         ...                                      ...    ...
# 257429   257430  reutlingen, baden-wuerttemberg, germany  200.0
# 261553   261554                    arak, tennessee, iran  143.0
# 264933   264934                    madrid, madrid, spain  140.0
# 275582   275583        koblenz, rheinland-pfalz, germany  189.0
# 276047   276048                      wien, wien, austria  127.0
#
# [78 rows x 3 columns]

# %%
users.Location.value_counts()
# Out:
# london, england, united kingdom                  2506
# toronto, ontario, canada                         2250
# sydney, new south wales, australia               1744
# melbourne, victoria, australia                   1708
# portland, oregon, usa                            1629
#                                                  ...
# gneisenaustr. 3, nordrhein-westfalen, germany       1
# -, bayern, germany                                  1
# bouchegouf, guelma, algeria                         1
# indiana and philadelphia, pennsylvania, usa         1
# tacoma, washington, united kingdom                  1
# Name: Location, Length: 57339, dtype: int64

# %% [markdown]
# # **Merge DataFrames**

# %%
df = ratings.merge(books, on= 'ISBN', how = 'inner')

# %%
df = df.merge(users, on = 'User-ID', how = 'inner')

# %%
df.drop(columns = ['Image-URL-S', 'Image-URL-L'], inplace = True) 
df.rename(columns = {"User-ID":'Uid',"Book-Rating":'Rating',"Book-Title":'Title',"Book-Author":'Author',"Year-Of-Publication":'Pub_Year',
                     "Image-URL-M":'Image_Url',}, inplace = True)

# %% [markdown]
# # Understand Final DataFrame

# %%
df.head()
# Out:
#       Uid        ISBN  Rating              Title           Author  Pub_Year  \
# 0  276726  0155061224       5   rites of passage       judith rae      2001
# 1  159181  0155061224       0   rites of passage       judith rae      2001
# 2  276727  0446520802       0       the notebook  nicholas sparks      1996
# 3  278418  0446520802       0       the notebook  nicholas sparks      1996
# 4  278418  0671537458       0  waiting to exhale   terry mcmillan      1995
#
#       Publisher                                          Image_Url  \
# 0        heinle  http://images.amazon.com/images/p/0155061224.0...
# 1        heinle  http://images.amazon.com/images/p/0155061224.0...
# 2  warner books  http://images.amazon.com/images/p/0446520802.0...
# 3  warner books  http://images.amazon.com/images/p/0446520802.0...
# 4        pocket  http://images.amazon.com/images/p/0671537458.0...
#
#                         Location   Age
# 0       seattle, washington, usa   NaN
# 1       seattle, washington, usa  28.0
# 2  h, new south wales, australia  16.0
# 3           omaha, nebraska, usa   NaN
# 4           omaha, nebraska, usa   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 946676 entries, 0 to 946675
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Uid        946676 non-null  int64
#  1   ISBN       946676 non-null  object
#  2   Rating     946676 non-null  int64
#  3   Title      946676 non-null  object
#  4   Author     946675 non-null  object
#  5   Pub_Year   946676 non-null  int64
#  6   Publisher  946675 non-null  object
#  7   Image_Url  946676 non-null  object
#  8   Location   946676 non-null  object
#  9   Age        691798 non-null  float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 79.4+ MB

# %%
# total number of unique books 
books.ISBN.nunique()
# Out:
# 271043

# %%
# number of duplicaete rows in the dataframe 
len(df[df.duplicated()])
# Out:
# 410

# %%
# drop duplicaete values 
df.drop_duplicates(inplace = True)

# %%
# Null Values 
df.isnull().sum()
# Out:
# Uid               0
# ISBN              0
# Rating            0
# Title             0
# Author            1
# Pub_Year          0
# Publisher         1
# Image_Url         0
# Location          0
# Age          254746
# dtype: int64

# %%
# Fill Age null values by mean
age_mean = df.Age.mean() 
df['Age'].fillna(age_mean, inplace = True)

# %%
# drop Null values of Author and Publisher column
df.dropna(inplace = True)

# %%
# books which have publish date after 2021
pd.set_option('max_colwidth', 100) 
df[df.loc[:,'Pub_Year' ] > 2021]
# Out:
#            Uid        ISBN  Rating  \
# 12273    11676  0671746103       0
# 31569   203240  0671791990       0
# 33540   230522  0671746103       0
# 36958   234623  0394701658       0
# 84935   198711  0671791990       0
# 152847  212898  0671740989       0
# 206104   88283  3442436893       0
# 218500   76626  0140301690       0
# 245246   82831  0140301690       7
# 267204  276762  0380000059       0
# 273887   13082  0671746103       0
# 297842  100459  0870446924       0
# 298508  127429  0671791990       0
# 307890  201548  3442436893       9
# 319500   69042  0671746103       0
# 327780  189334  0394701658       0
# 348733   41841  0671791990       6
# 359193  197659  0671746103       8
# 359287  197659  0671791990       8
# 363154   89207  3442436893       9
# 368691  245410  0870446924       0
# 373749   62881  0671746103       0
# 373790   62881  0394701658       0
# 380145   55493  0671791990       5
# 414470  194957  3442436893       6
# 417228   41700  0140301690       7
# 422048   40029  0140301690      10
# 434715  180571  3442436893       0
# 521284  215006  0394701658      10
# 523166  240144  0140301690       0
# 524940  250962  0671746103       0
# 589515   31556  0671791990       0
# 592396   29419  0671791990       0
# 592450  235221  0671791990       0
# 594625  174596  0870449842       6
# 614265  219254  0394701658       0
# 616984   39159  0870449842       7
# 620418  191187  0671746103       0
# 637863  260944  0140201092       0
# 686206  115234  0671746103       0
# 722617  188951  0671746103       9
# 729522  151608  0684718022       0
# 736291  232080  0671791990       7
# 800505   88330  0394701658       9
# 827849   29989  0671746103       5
# 842745  117037  0671266500       9
# 874789   97653  0870449842       9
# 884979  165503  0140201092      10
# 908373   20534  0671746103       4
# 908374  234157  0671746103       6
# 928391  228097  0870449842       8
# 928413  153674  0394701658       0
# 933451  100649  0394701658       0
#
#                                                                                 Title  \
# 12273                       my teacher fried my brains (rack size) (my teacher books)
# 31569                    my teacher flunked the planet (rack size) (my teacher books)
# 33540                       my teacher fried my brains (rack size) (my teacher books)
# 36958                                                    three plays of eugene oneill
# 84935                    my teacher flunked the planet (rack size) (my teacher books)
# 152847                                    football super teams : football super teams
# 206104                                    das groã?â?e bã?â¶se- mã?â¤dchen- lesebuch.
# 218500  alice's adventures in wonderland and through the looking glass (puffin books)
# 245246  alice's adventures in wonderland and through the looking glass (puffin books)
# 267204                                                                          clout
# 273887                      my teacher fried my brains (rack size) (my teacher books)
# 297842                             field guide to the birds of north america, 3rd ed.
# 298508                   my teacher flunked the planet (rack size) (my teacher books)
# 307890                                    das groã?â?e bã?â¶se- mã?â¤dchen- lesebuch.
# 319500                      my teacher fried my brains (rack size) (my teacher books)
# 327780                                                   three plays of eugene oneill
# 348733                   my teacher flunked the planet (rack size) (my teacher books)
# 359193                      my teacher fried my brains (rack size) (my teacher books)
# 359287                   my teacher flunked the planet (rack size) (my teacher books)
# 363154                                    das groã?â?e bã?â¶se- mã?â¤dchen- lesebuch.
# 368691                             field guide to the birds of north america, 3rd ed.
# 373749                      my teacher fried my brains (rack size) (my teacher books)
# 373790                                                   three plays of eugene oneill
# 380145                   my teacher flunked the planet (rack size) (my teacher books)
# 414470                                    das groã?â?e bã?â¶se- mã?â¤dchen- lesebuch.
# 417228  alice's adventures in wonderland and through the looking glass (puffin books)
# 422048  alice's adventures in wonderland and through the looking glass (puffin books)
# 434715                                    das groã?â?e bã?â¶se- mã?â¤dchen- lesebuch.
# 521284                                                   three plays of eugene oneill
# 523166  alice's adventures in wonderland and through the looking glass (puffin books)
# 524940                      my teacher fried my brains (rack size) (my teacher books)
# 589515                   my teacher flunked the planet (rack size) (my teacher books)
# 592396                   my teacher flunked the planet (rack size) (my teacher books)
# 592450                   my teacher flunked the planet (rack size) (my teacher books)
# 594625                                                               crossing america
# 614265                                                   three plays of eugene oneill
# 616984                                                               crossing america
# 620418                      my teacher fried my brains (rack size) (my teacher books)
# 637863                                  outline of european architecture (pelican s.)
# 686206                      my teacher fried my brains (rack size) (my teacher books)
# 722617                      my teacher fried my brains (rack size) (my teacher books)
# 729522                                        in our time: stories (scribner classic)
# 736291                   my teacher flunked the planet (rack size) (my teacher books)
# 800505                                                   three plays of eugene oneill
# 827849                      my teacher fried my brains (rack size) (my teacher books)
# 842745                                   forest people (touchstone books (hardcover))
# 874789                                                               crossing america
# 884979                                  outline of european architecture (pelican s.)
# 908373                      my teacher fried my brains (rack size) (my teacher books)
# 908374                      my teacher fried my brains (rack size) (my teacher books)
# 928391                                                               crossing america
# 928413                                                   three plays of eugene oneill
# 933451                                                   three plays of eugene oneill
#
#                              Author  Pub_Year  \
# 12273                       coville      2030
# 31569                 bruce coville      2030
# 33540                       coville      2030
# 36958                eugene o'neill      2038
# 84935                 bruce coville      2030
# 152847                  bill gutman      2030
# 206104                  kathy lette      2026
# 218500                lewis carroll      2050
# 245246                lewis carroll      2050
# 267204                   d. gibbons      2024
# 273887                      coville      2030
# 297842  national geographic society      2030
# 298508                bruce coville      2030
# 307890                  kathy lette      2026
# 319500                      coville      2030
# 327780               eugene o'neill      2038
# 348733                bruce coville      2030
# 359193                      coville      2030
# 359287                bruce coville      2030
# 363154                  kathy lette      2026
# 368691  national geographic society      2030
# 373749                      coville      2030
# 373790               eugene o'neill      2038
# 380145                bruce coville      2030
# 414470                  kathy lette      2026
# 417228                lewis carroll      2050
# 422048                lewis carroll      2050
# 434715                  kathy lette      2026
# 521284               eugene o'neill      2038
# 523166                lewis carroll      2050
# 524940                      coville      2030
# 589515                bruce coville      2030
# 592396                bruce coville      2030
# 592450                bruce coville      2030
# 594625  national geographic society      2030
# 614265               eugene o'neill      2038
# 616984  national geographic society      2030
# 620418                      coville      2030
# 637863             nikolaus pevsner      2050
# 686206                      coville      2030
# 722617                      coville      2030
# 729522             ernest hemingway      2030
# 736291                bruce coville      2030
# 800505               eugene o'neill      2038
# 827849                      coville      2030
# 842745            colin m. turnbull      2030
# 874789  national geographic society      2030
# 884979             nikolaus pevsner      2050
# 908373                      coville      2030
# 908374                      coville      2030
# 928391  national geographic society      2030
# 928413               eugene o'neill      2038
# 933451               eugene o'neill      2038
#
#                                          Publisher  \
# 12273                                      aladdin
# 31569                                      aladdin
# 33540                                      aladdin
# 36958                            vintage books usa
# 84935                                      aladdin
# 152847  simon &amp; schuster children's publishing
# 206104                                    goldmann
# 218500                                puffin books
# 245246                                puffin books
# 267204                                        avon
# 273887                                     aladdin
# 297842                         national geographic
# 298508                                     aladdin
# 307890                                    goldmann
# 319500                                     aladdin
# 327780                           vintage books usa
# 348733                                     aladdin
# 359193                                     aladdin
# 359287                                     aladdin
# 363154                                    goldmann
# 368691                         national geographic
# 373749                                     aladdin
# 373790                           vintage books usa
# 380145                                     aladdin
# 414470                                    goldmann
# 417228                                puffin books
# 422048                                puffin books
# 434715                                    goldmann
# 521284                           vintage books usa
# 523166                                puffin books
# 524940                                     aladdin
# 589515                                     aladdin
# 592396                                     aladdin
# 592450                                     aladdin
# 594625                         national geographic
# 614265                           vintage books usa
# 616984                         national geographic
# 620418                                     aladdin
# 637863                                 penguin usa
# 686206                                     aladdin
# 722617                                     aladdin
# 729522                               collier books
# 736291                                     aladdin
# 800505                           vintage books usa
# 827849                                     aladdin
# 842745                        simon &amp; schuster
# 874789                         national geographic
# 884979                                 penguin usa
# 908373                                     aladdin
# 908374                                     aladdin
# 928391                         national geographic
# 928413                           vintage books usa
# 933451                           vintage books usa
#
#                                                            Image_Url  \
# 12273   http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 31569   http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 33540   http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 36958   http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 84935   http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 152847  http://images.amazon.com/images/p/0671740989.01.mzzzzzzz.jpg
# 206104  http://images.amazon.com/images/p/3442436893.01.mzzzzzzz.jpg
# 218500  http://images.amazon.com/images/p/0140301690.01.mzzzzzzz.jpg
# 245246  http://images.amazon.com/images/p/0140301690.01.mzzzzzzz.jpg
# 267204  http://images.amazon.com/images/p/0380000059.01.mzzzzzzz.jpg
# 273887  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 297842  http://images.amazon.com/images/p/0870446924.01.mzzzzzzz.jpg
# 298508  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 307890  http://images.amazon.com/images/p/3442436893.01.mzzzzzzz.jpg
# 319500  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 327780  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 348733  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 359193  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 359287  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 363154  http://images.amazon.com/images/p/3442436893.01.mzzzzzzz.jpg
# 368691  http://images.amazon.com/images/p/0870446924.01.mzzzzzzz.jpg
# 373749  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 373790  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 380145  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 414470  http://images.amazon.com/images/p/3442436893.01.mzzzzzzz.jpg
# 417228  http://images.amazon.com/images/p/0140301690.01.mzzzzzzz.jpg
# 422048  http://images.amazon.com/images/p/0140301690.01.mzzzzzzz.jpg
# 434715  http://images.amazon.com/images/p/3442436893.01.mzzzzzzz.jpg
# 521284  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 523166  http://images.amazon.com/images/p/0140301690.01.mzzzzzzz.jpg
# 524940  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 589515  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 592396  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 592450  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 594625  http://images.amazon.com/images/p/0870449842.01.mzzzzzzz.jpg
# 614265  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 616984  http://images.amazon.com/images/p/0870449842.01.mzzzzzzz.jpg
# 620418  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 637863  http://images.amazon.com/images/p/0140201092.01.mzzzzzzz.jpg
# 686206  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 722617  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 729522  http://images.amazon.com/images/p/0684718022.01.mzzzzzzz.jpg
# 736291  http://images.amazon.com/images/p/0671791990.01.mzzzzzzz.jpg
# 800505  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 827849  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 842745  http://images.amazon.com/images/p/0671266500.01.mzzzzzzz.jpg
# 874789  http://images.amazon.com/images/p/0870449842.01.mzzzzzzz.jpg
# 884979  http://images.amazon.com/images/p/0140201092.01.mzzzzzzz.jpg
# 908373  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 908374  http://images.amazon.com/images/p/0671746103.01.mzzzzzzz.jpg
# 928391  http://images.amazon.com/images/p/0870449842.01.mzzzzzzz.jpg
# 928413  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
# 933451  http://images.amazon.com/images/p/0394701658.01.mzzzzzzz.jpg
#
#                                         Location        Age
# 12273                              n/a, n/a, n/a  37.394772
# 31569                   st. louis, missouri, usa  32.000000
# 33540            colorado springs, colorado, usa  52.000000
# 36958                    scarborough, maine, usa  37.394772
# 84935              little canada, minnesota, usa  62.000000
# 152847            la ronge, saskatchewan, canada  37.394772
# 206104                 hamburg, hamburg, germany  24.000000
# 218500           london, england, united kingdom  38.000000
# 245246                 nashville, tennessee, usa  21.000000
# 267204    duisburg, nordrhein-westfalen, germany  25.000000
# 273887               bellwood, pennsylvania, usa  37.394772
# 297842                 bay area, california, usa  38.000000
# 298508                kansas city, missouri, usa  23.000000
# 307890  rheinfelden, baden-wuerttemberg, germany  29.000000
# 319500           drayton valley, alberta, canada  55.000000
# 327780                   ottawa, ontario, canada  49.000000
# 348733            sherwood park, alberta, canada  37.394772
# 359193                indiana, pennsylvania, usa  49.000000
# 359287                indiana, pennsylvania, usa  49.000000
# 363154        gateshead, england, united kingdom  26.000000
# 368691                   san antonio, texas, usa  28.000000
# 373749                 milwaukee, wisconsin, usa  39.000000
# 373790                 milwaukee, wisconsin, usa  39.000000
# 380145                  chatham, ontario, canada  35.000000
# 414470      reinbek, schleswig-holstein, germany  41.000000
# 417228            kerzers, fribourg, switzerland  42.000000
# 422048               lausanne, vaud, switzerland  26.000000
# 434715   bielefeld, nordrhein-westfalen, germany  52.000000
# 521284                  seattle, washington, usa  44.000000
# 523166                   muskego, wisconsin, usa  34.000000
# 524940       vancouver, british columbia, canada  24.000000
# 589515              chula vista, california, usa  51.000000
# 592396                    norcross, georgia, usa  37.394772
# 592450                   ottawa, ontario, canada  45.000000
# 594625            jackson heights, new york, usa  37.394772
# 614265                   ottawa, ontario, canada  37.394772
# 616984         west los angeles, california, usa  37.394772
# 620418                   cedar rapids, iowa, usa  37.394772
# 637863               stratford, connecticut, usa  37.394772
# 686206                 st. peters, missouri, usa  32.000000
# 722617                    valdosta, georgia, usa  24.000000
# 729522                  orillia, ontario, canada  37.394772
# 736291              silver city, new mexico, usa  53.000000
# 800505            hendersonville, tennessee, usa  37.394772
# 827849                    chaffee, new york, usa  40.000000
# 842745                        montreal, , canada  45.000000
# 874789             apple valley, california, usa  37.394772
# 884979                ploiesti, prahova, romania  17.000000
# 908373                   erie, pennsylvania, usa  16.000000
# 908374                   o`fallon, missouri, usa  37.394772
# 928391             wasaga beach, ontario, canada  37.394772
# 928413          state college, pennsylvania, usa  37.394772
# 933451                   ottawa, ontario, canada  37.394772

# %% [markdown]
# ### Yearly Reviews

# %%
# year wise movies 
yearly_books = df.value_counts('Pub_Year')
yearly_books = yearly_books.loc[(yearly_books.index >= 1920) & (yearly_books.index < 2010) ]
plt.figure(figsize= (25,8))
plt.title('year wise reviews of books')
plt.xlabel('years')
plt.ylabel('Number of reviews')
plt.xticks(np.arange(1920,2007, 1), rotation = 60)
plt.bar( yearly_books.index,yearly_books.values , width = 0.8 )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Distribution of ages

# %%
# counting the distribution of age 
plt.figure(figsize = (20,15)) 
plt.title('Age count') 
plt.xlabel('Ages') 
plt.ylabel('Count of Ages') 
plt.xticks(rotation = 90) 
sns.countplot(x ='Age', data = df) 
plt.show()

# %% [markdown]
# ### Most reviewed Authors

# %%
# 
from PIL import Image 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator 
# creating a string for the word cloud 
rev_2000 =  df.Author.value_counts()[df.Author.value_counts() >= 2000] 
word = list() 
for reviews , name in zip(rev_2000.values, rev_2000.index): 
  name = name.replace(' ', '_') 
  name += ' ' 
  word.append(name * reviews) 
words = ' '.join(word) 

# mask = np.array(Image.open("/content/drive/MyDrive/AlmaBetter /Capstone Project/Book Recommendation System/pngwing.com (3).png")) 

word_cloud = WordCloud( collocations=  False, background_color=None, mask  = None).generate(words) 
plt.figure(figsize=[10,7]) 
# Display the generated Word Cloud 
plt.imshow(word_cloud, interpolation='bilinear' ) 
plt.axis("off") 
# store to file 
plt.savefig("authors.png", format="png") 
plt.show()

# %% [markdown]
# ### fetch Top Rated Books

# %%
# all those rows which have number of ratings above 100 
top = ratings.merge(books, on= 'ISBN', how = 'inner')['ISBN'].value_counts() > 100
temp_df = ratings.merge(books, on= 'ISBN', how = 'inner')
temp_df = temp_df[temp_df["ISBN"].isin(top[top == True].index)]

# %%
temp_df.head()
# Out:
#    User-ID        ISBN  Book-Rating    Book-Title      Book-Author  \
# 2   276727  0446520802            0  the notebook  nicholas sparks
# 3   278418  0446520802            0  the notebook  nicholas sparks
# 4      638  0446520802            0  the notebook  nicholas sparks
# 5     3363  0446520802            0  the notebook  nicholas sparks
# 6     7158  0446520802           10  the notebook  nicholas sparks
#
#    Year-Of-Publication     Publisher  \
# 2                 1996  warner books
# 3                 1996  warner books
# 4                 1996  warner books
# 5                 1996  warner books
# 6                 1996  warner books
#
#                                                     Image-URL-S  \
# 2  http://images.amazon.com/images/p/0446520802.01.thumbzzz.jpg
# 3  http://images.amazon.com/images/p/0446520802.01.thumbzzz.jpg
# 4  http://images.amazon.com/images/p/0446520802.01.thumbzzz.jpg
# 5  http://images.amazon.com/images/p/0446520802.01.thumbzzz.jpg
# 6  http://images.amazon.com/images/p/0446520802.01.thumbzzz.jpg
#
#                                                     Image-URL-M  \
# 2  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 3  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 4  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 5  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 6  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
#
#                                                     Image-URL-L
# 2  http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg
# 3  http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg
# 4  http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg
# 5  http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg
# 6  http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg

# %%
(temp_df.groupby('Book-Title')['Book-Title'].count() > 100).index
# Out:
# Index(['1984', '1st to die: a novel', '2nd chance', '4 blondes',
#        '\o\" is for outlaw"',
#        'a beautiful mind: the life of mathematical genius and nobel laureate john nash',
#        'a bend in the road', 'a case of need',
#        'a child called \it\": one child's courage to survive"',
#        'a civil action',
#        ...
#        'who moved my cheese? an amazing way to deal with change in your work and in your life',
#        'wicked: the life and times of the wicked witch of the west', 'wifey',
#        'wild animus', 'winter moon', 'wish you well', 'without remorse',
#        'year of wonders', 'you belong to me',
#        'zen and the art of motorcycle maintenance: an inquiry into values'],
#       dtype='object', name='Book-Title', length=599)

# %%
# books with minimum 100 ratings 
min_100_rating = temp_df.loc[temp_df['Book-Title'].isin((temp_df.groupby('Book-Title')['Book-Title'].count() > 150).index ) ]


# Top books filtering based on mean of ratings
top_books = min_100_rating.groupby('Book-Title')['Book-Rating'].mean().sort_values(ascending = False)

# %%
# create a pkl file of top 50 books by average rating
top_50_books = top_books[:51]
pickle.dump(top_50_books,open('top_50_books.pkl','wb'))

# %%
top_50_books
# Out:
# Book-Title
# harry potter and the sorcerer's stone (book 1)                                                                    6.363095
# harry potter and the prisoner of azkaban (book 3)                                                                 5.867612
# harry potter and the goblet of fire (book 4)                                                                      5.824289
# harry potter and the chamber of secrets (book 2)                                                                  5.343570
# ender's game (ender wiggins saga (paperback))                                                                     5.302564
# the perks of being a wallflower                                                                                   5.194175
# the hobbit : the enchanting prelude to the lord of the rings                                                      5.007117
# to kill a mockingbird                                                                                             4.920308
# the giver (21st century reference)                                                                                4.915730
# ishmael: an adventure of the mind and spirit                                                                      4.907407
# anne frank: the diary of a young girl                                                                             4.820144
# charlotte's web (trophy newbery)                                                                                  4.782946
# the other boleyn girl                                                                                             4.756410
# animal farm                                                                                                       4.695122
# the last juror                                                                                                    4.654867
# the da vinci code                                                                                                 4.652322
# the catcher in the rye                                                                                            4.635236
# dragonfly in amber                                                                                                4.632812
# stranger in a strange land (remembering tomorrow)                                                                 4.615385
# 1984                                                                                                              4.614583
# dune (remembering tomorrow)                                                                                       4.609589
# brave new world                                                                                                   4.554622
# the great gatsby                                                                                                  4.553073
# east of eden (oprah's book club)                                                                                  4.549618
# the five people you meet in heaven                                                                                4.543326
# the stand: complete and uncut                                                                                     4.534351
# the fellowship of the ring (the lord of the rings, part 1)                                                        4.505837
# coraline                                                                                                          4.504348
# the lovely bones: a novel                                                                                         4.468726
# prodigal summer: a novel                                                                                          4.450593
# naked                                                                                                             4.419355
# where the red fern grows                                                                                          4.410714
# fahrenheit 451                                                                                                    4.408100
# tuesdays with morrie: an old man, a young man, and life's greatest lesson                                         4.406650
# a wrinkle in time                                                                                                 4.398089
# siddhartha                                                                                                        4.376238
# the valley of horses                                                                                              4.361538
# stupid white men ...and other sorry excuses for the state of the nation!                                          4.356890
# night                                                                                                             4.337017
# the red tent (bestselling backlist)                                                                               4.334716
# year of wonders                                                                                                   4.331361
# memoirs of a geisha uk                                                                                            4.312883
# the tao of pooh                                                                                                   4.296296
# the two towers (the lord of the rings, part 2)                                                                    4.276836
# holes (yearling newbery)                                                                                          4.272727
# neverwhere                                                                                                        4.265823
# atlas shrugged                                                                                                    4.252252
# one flew over the cuckoo's nest                                                                                   4.250000
# good omens                                                                                                        4.244048
# a walk in the woods: rediscovering america on the appalachian trail (official guides to the appalachian trail)    4.243902
# dude, where's my country?                                                                                         4.240000
# Name: Book-Rating, dtype: float64

# %%
# top 50 highest rated Books
import matplotlib
plt.figure(figsize= (20,15),)
matplotlib.style.use('dark_background')
plt.title('Top 50 Books')
plt.xlabel('Books')
plt.ylabel('Average Rating')
plt.xticks(rotation = 90)
plt.bar( top_books.index[:51],top_books.values[:51] , width = 0.8,  )
plt.savefig('top_50_books.png' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ### Add one Additional Feature Age_segment

# %%
# age group segmentation
def age_segment(age):
  if age < 13:
    return 'kid'
  elif age < 20:
    return 'teen'
  elif age < 45:
    return 'Adult'
  elif age >=45:
    return 'old'
age_cat = df.Age.apply(lambda x: age_segment(x))

# add that feature to df
df['age_segment'] = age_cat

# %% [markdown]
# ### Segment wise ages of the Population

# %%
# sns.countplot(x = df['age_segment'], )
plt.title('age segmentation')
labels = ['Adult', 'teen', 'old', 'kid']
plt.pie(x = df['age_segment'].value_counts(), explode = [0.,0.15,0.25,0.35], labels = labels, rotatelabels= False, 
        autopct = '%2.0f%%', pctdistance= 0.9, wedgeprops= None, )
plt.show()

# %%
df.head()
# Out:
#       Uid        ISBN  Rating              Title           Author  Pub_Year  \
# 0  276726  0155061224       5   rites of passage       judith rae      2001
# 1  159181  0155061224       0   rites of passage       judith rae      2001
# 2  276727  0446520802       0       the notebook  nicholas sparks      1996
# 3  278418  0446520802       0       the notebook  nicholas sparks      1996
# 4  278418  0671537458       0  waiting to exhale   terry mcmillan      1995
#
#       Publisher                                                     Image_Url  \
# 0        heinle  http://images.amazon.com/images/p/0155061224.01.mzzzzzzz.jpg
# 1        heinle  http://images.amazon.com/images/p/0155061224.01.mzzzzzzz.jpg
# 2  warner books  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 3  warner books  http://images.amazon.com/images/p/0446520802.01.mzzzzzzz.jpg
# 4        pocket  http://images.amazon.com/images/p/0671537458.01.mzzzzzzz.jpg
#
#                         Location        Age age_segment
# 0       seattle, washington, usa  37.394772       Adult
# 1       seattle, washington, usa  28.000000       Adult
# 2  h, new south wales, australia  16.000000        teen
# 3           omaha, nebraska, usa  37.394772       Adult
# 4           omaha, nebraska, usa  37.394772       Adult

# %% [markdown]
# ### Selecting users which have rated atleast 5 books
# ## Selecting books which are rated atleast 10 times
# ### To Avoid cold Start problem and to recommend books which genuinely have a good number of reviewers we need to sort the data

# %%
# keeping books which are rated atleast 10 times...
books_to_drop = df['Title'].value_counts()[df['Title'].value_counts() <= 80].index
df.drop( df[df['Title'].isin(books_to_drop)].index , inplace = True)
print(f"shape after removing books is {df.shape}") 
print(f"unique user {df.Uid.nunique()}")   
print(f"unique Books {df.Title.nunique()}")
# Out:
# shape after removing books is (194183, 11)
# unique user 38997
# unique Books 1144

# %%
# # keeping the users which have rated minimum 5 books...
print(f"shape before removing users is {df.shape}")
users_to_drop = df.Uid.value_counts()[df.Uid.value_counts() < 30].index
df.drop( df[df['Uid'].isin(users_to_drop)].index , inplace = True)
print(f"shape after removing users is {df.shape}")
print(f"unique user {df.Uid.nunique()}")      
print(f"unique Books {df.Title.nunique()}")
# Out:
# shape before removing users is (194183, 11)
# shape after removing users is (89451, 11)
# unique user 1148
# unique Books 1144

# %%
# except rating make all features as str
df = df.astype(str)
df['Rating'] = df['Rating'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89451 entries, 3 to 766965
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Uid          89451 non-null  object
#  1   ISBN         89451 non-null  object
#  2   Rating       89451 non-null  int64
#  3   Title        89451 non-null  object
#  4   Author       89451 non-null  object
#  5   Pub_Year     89451 non-null  object
#  6   Publisher    89451 non-null  object
#  7   Image_Url    89451 non-null  object
#  8   Location     89451 non-null  object
#  9   Age          89451 non-null  object
#  10  age_segment  89451 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 8.2+ MB

# %%
# list of all those books which are into model
unique_books = df.drop_duplicates(subset= 'Title')

# %%
df.head(1)
# Out:
#    User-ID        ISBN  Book-Rating        Book-Title Book-Author  \
# 0   276726  0155061224            5  rites of passage  judith rae
#
#    Year-Of-Publication Publisher  \
# 0                 2001    heinle
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/p/0155061224.01.thumbzzz.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/p/0155061224.01.mzzzzzzz.jpg
#
#                                                     Image-URL-L  \
# 0  http://images.amazon.com/images/p/0155061224.01.lzzzzzzz.jpg
#
#                    Location  Age
# 0  seattle, washington, usa  NaN

# %%
df['Image-URL-L'].values
# Out:
# array(['http://images.amazon.com/images/p/0155061224.01.lzzzzzzz.jpg',
#        'http://images.amazon.com/images/p/0155061224.01.lzzzzzzz.jpg',
#        'http://images.amazon.com/images/p/0446520802.01.lzzzzzzz.jpg',
#        ...,
#        'http://images.amazon.com/images/p/0553571001.01.lzzzzzzz.jpg',
#        'http://images.amazon.com/images/p/0689822294.01.lzzzzzzz.jpg',
#        'http://images.amazon.com/images/p/0583307841.01.lzzzzzzz.jpg'],
#       dtype=object)

# %% [markdown]
# # Save new DF to csv which we will use in modelling Notebook

# %%
df.to_csv('Books_data.csv')

# %%
# unique_books.to_csv('unique_books.csv')
book_file = open('unique_books.pkl', 'wb')
pickle.dump(unique_books, book_file)
